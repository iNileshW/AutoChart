# %% [markdown]
# # AutoChart Working Notebook

# %%
import pandas as pd
import geopandas

# %%
gdf_new = geopandas.read_file(r"data\New_Chart_Scheme.shp")

gdf_new.head(1)
# Out:
#   comments   Chart     Panel_Name  Pan_Scale  Panel_ID Paper_Size  GTL  \
# 0      NaN  GB1013  Helford River      12500         0         A2  Ash
#
#                                             geometry
# 0  POLYGON ((-5.21571 50.08054, -5.21571 50.11422...

# %%
gdf_new.shape
# Out:
# (91, 8)

# %%
gdf_new.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   comments    24 non-null     str
#  1   Chart       91 non-null     str
#  2   Panel_Name  91 non-null     str
#  3   Pan_Scale   91 non-null     int64
#  4   Panel_ID    91 non-null     int32
#  5   Paper_Size  91 non-null     str
#  6   GTL         91 non-null     str
#  7   geometry    91 non-null     geometry
# dtypes: geometry(1), int32(1), int64(1), str(5)
# memory usage: 5.5 KB

# %%
gdf_new['Chart'].unique()
# Out:
# <StringArray>
# ['GB1013', 'GB1009', 'GB1010', 'GB1011', 'GB1014', 'GB1012', 'GB1016',
#  'GB1017', 'GB1015', 'GB1018', 'GB1019', 'GB1020', 'GB1025', 'GB1026',
#  'GB1029', 'GB1021', 'GB1022', 'GB1023', 'GB1024', 'GB1027', 'GB1028',
#  'GB1030', 'GB1031', 'GB1039', 'GB1032', 'GB1035', 'GB1033', 'GB1034',
#  'GB1036', 'GB1037', 'GB1038',  'GB102',  'GB503',  'GB502',  'GB501',
#   'GB500',  'GB100',  'GB101', 'GB1003', 'GB1004', 'GB1005', 'GB1006',
#  'GB1007', 'GB1008', 'GB5000', 'GB5001', 'GB5002', 'GB5003', 'GB5004',
#  'GB5005', 'GB5006', 'GB5007', 'GB5008', 'GB5009', 'GB5010', 'GB5011',
#  'GB5012', 'GB5013', 'GB5014', 'GB5015', 'GB5016', 'GB1000', 'GB1001',
#  'GB1002']
# Length: 64, dtype: str

# %%
gdf_old = geopandas.read_file(r"data\Old_Chart_Scheme.shp")
gdf_old.head(1)
# Out:
#    SDOC_ID      SDOC_NAME          SOURCE_NAM  SDT_ID            SDT_NAME  \
# 0  2134168  0147_6 F Looe  RSDRA2019000295185    1950  UKHO Chart - Panel
#
#         DATUM  CRS_ID                                         CRS_PARAMS  \
# 0  D_WGS_1984  432627  PROJCS["WGS84_Transverse_Mercator",GEOGCS["GCS...
#
#   PUBLICATIO RECEIPTDAT  ... GBENC_NAVP GBENC_UPDA GBENC_UP_1         STATUS  \
# 0 2017-02-09 2019-12-09  ...       None        NaT       None  ASSESS_CLOSED
#
#   STATUS_OP STATUS_DAT   GEO_ID SHAPE_AREA SHAPE_LEN  \
# 0     10738 2019-12-09  1836968        0.0       0.0
#
#                                             geometry
# 0  POLYGON ((-4.45944 50.3433, -4.45945 50.35724,...
#
# [1 rows x 70 columns]

# %%
gdf_old.shape
# Out:
# (196, 70)

# %%
gdf_old.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 70 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SDOC_ID     196 non-null    int64
#  1   SDOC_NAME   196 non-null    str
#  2   SOURCE_NAM  196 non-null    str
#  3   SDT_ID      196 non-null    int64
#  4   SDT_NAME    196 non-null    str
#  5   DATUM       196 non-null    str
#  6   CRS_ID      196 non-null    int64
#  7   CRS_PARAMS  196 non-null    str
#  8   PUBLICATIO  196 non-null    datetime64[ms]
#  9   RECEIPTDAT  196 non-null    datetime64[ms]
#  10  UKHOVERSIO  196 non-null    str
#  11  PRODUCEDBY  196 non-null    str
#  12  PRODUCED_1  29 non-null     str
#  13  PRODUCED_2  0 non-null      object
#  14  IPROWNER1   196 non-null    str
#  15  PROTECTIVE  196 non-null    str
#  16  AUTHORITAT  194 non-null    str
#  17  SUBJECTMAT  0 non-null      object
#  18  SUBJECTM_1  0 non-null      object
#  19  SUBJECTM_2  0 non-null      object
#  20  SUPPLIEDBY  0 non-null      object
#  21  SUPPLIED_1  0 non-null      object
#  22  SUPPLIED_2  0 non-null      object
#  23  SUPPLIED_3  0 non-null      object
#  24  SUPPLIED_4  0 non-null      object
#  25  SCALE       196 non-null    float64
#  26  DEPTHUNITS  196 non-null    str
#  27  SPATIALREF  196 non-null    float64
#  28  VALIDATED   196 non-null    str
#  29  CHART_PREF  0 non-null      object
#  30  CHART_NUMB  196 non-null    float64
#  31  CHART_SUFF  0 non-null      object
#  32  CHART_TYPE  0 non-null      object
#  33  CHART_CORR  196 non-null    float64
#  34  CHART_CO_1  196 non-null    float64
#  35  CHART_REVI  0 non-null      datetime64[ms]
#  36  CHART_CANC  0 non-null      datetime64[ms]
#  37  CHART_INTN  196 non-null    float64
#  38  CHART_MAIN  0 non-null      object
#  39  CHART_GENE  0 non-null      object
#  40  CHART_SPEC  0 non-null      object
#  41  CHART_SP_1  0 non-null      object
#  42  PANEL_CHAR  0 non-null      object
#  43  PANEL_CH_1  196 non-null    float64
#  44  PANEL_CH_2  105 non-null    str
#  45  PANEL_IDEN  196 non-null    str
#  46  PANEL_MAIN  196 non-null    str
#  47  PANEL_GENE  18 non-null     str
#  48  PANEL_MULT  196 non-null    str
#  49  PANEL_SPEC  3 non-null      str
#  50  PANEL_SP_1  2 non-null      str
#  51  PUBLICAT_1  196 non-null    float64
#  52  PUBLICAT_2  0 non-null      object
#  53  PUBLICAT_3  0 non-null      object
#  54  PUBLICAT_4  0 non-null      object
#  55  PUBLICAT_5  0 non-null      datetime64[ms]
#  56  GBENC_CELL  0 non-null      object
#  57  GBENC_EDIT  0 non-null      object
#  58  GBENC_FILE  0 non-null      object
#  59  GBENC_ISSU  0 non-null      datetime64[ms]
#  60  GBENC_NAVP  0 non-null      object
#  61  GBENC_UPDA  0 non-null      datetime64[ms]
#  62  GBENC_UP_1  0 non-null      object
#  63  STATUS      196 non-null    str
#  64  STATUS_OP   196 non-null    int64
#  65  STATUS_DAT  196 non-null    datetime64[ms]
#  66  GEO_ID      196 non-null    int64
#  67  SHAPE_AREA  196 non-null    float64
#  68  SHAPE_LEN   196 non-null    float64
#  69  geometry    196 non-null    geometry
# dtypes: datetime64[ms](8), float64(10), geometry(1), int64(5), object(25), str(21)
# memory usage: 107.3+ KB

# %%
gdf_old.to_file("my_file_gdf_old.geojson", driver="GeoJSON")

# %%
gdf_new.to_file("my_file_gdf_new.geojson", driver="GeoJSON")

# %%
gdf_plan_id=gdf_old[["PANEL_IDEN"]]
gdf_plan_id
# Out:
#     PANEL_IDEN
# 0       0147_6
# 1       2345_8
# 2       1182_1
# 3    5603_12_0
# 4     5608_2_2
# ..         ...
# 191     0031_3
# 192     1900_0
# 193     1902_0
# 194     1267_0
# 195     1967_1
#
# [196 rows x 1 columns]

# %%
gdf_new.columns
# Out:
# Index(['comments', 'Chart', 'Panel_Name', 'Pan_Scale', 'Panel_ID',
#        'Paper_Size', 'GTL', 'geometry'],
#       dtype='str')

# %%
gdf_old.columns
# Out:
# Index(['SDOC_ID', 'SDOC_NAME', 'SOURCE_NAM', 'SDT_ID', 'SDT_NAME', 'DATUM',
#        'CRS_ID', 'CRS_PARAMS', 'PUBLICATIO', 'RECEIPTDAT', 'UKHOVERSIO',
#        'PRODUCEDBY', 'PRODUCED_1', 'PRODUCED_2', 'IPROWNER1', 'PROTECTIVE',
#        'AUTHORITAT', 'SUBJECTMAT', 'SUBJECTM_1', 'SUBJECTM_2', 'SUPPLIEDBY',
#        'SUPPLIED_1', 'SUPPLIED_2', 'SUPPLIED_3', 'SUPPLIED_4', 'SCALE',
#        'DEPTHUNITS', 'SPATIALREF', 'VALIDATED', 'CHART_PREF', 'CHART_NUMB',
#        'CHART_SUFF', 'CHART_TYPE', 'CHART_CORR', 'CHART_CO_1', 'CHART_REVI',
#        'CHART_CANC', 'CHART_INTN', 'CHART_MAIN', 'CHART_GENE', 'CHART_SPEC',
#        'CHART_SP_1', 'PANEL_CHAR', 'PANEL_CH_1', 'PANEL_CH_2', 'PANEL_IDEN',
#        'PANEL_MAIN', 'PANEL_GENE', 'PANEL_MULT', 'PANEL_SPEC', 'PANEL_SP_1',
#        'PUBLICAT_1', 'PUBLICAT_2', 'PUBLICAT_3', 'PUBLICAT_4', 'PUBLICAT_5',
#        'GBENC_CELL', 'GBENC_EDIT', 'GBENC_FILE', 'GBENC_ISSU', 'GBENC_NAVP',
#        'GBENC_UPDA', 'GBENC_UP_1', 'STATUS', 'STATUS_OP', 'STATUS_DAT',
#        'GEO_ID', 'SHAPE_AREA', 'SHAPE_LEN', 'geometry'],
#       dtype='str')

# %%
import re
import numpy as np
import pandas as pd
import geopandas as gpd

# 1) Align CRS and move to a metric CRS for area-based overlap scoring
metric_crs = "EPSG:27700"

if gdf_old.crs != gdf_new.crs:
    gdf_new_aligned = gdf_new.to_crs(gdf_old.crs)
else:
    gdf_new_aligned = gdf_new.copy()

old_m = gdf_old.to_crs(metric_crs).copy()
new_m = gdf_new_aligned.to_crs(metric_crs).copy()

old_m["old_row"] = old_m.index
new_m["new_row"] = new_m.index

# 2) Normalize names and scales for attribute checks
def norm_text(value):
    if pd.isna(value):
        return None
    text = str(value).strip().lower()
    text = re.sub(r"[^a-z0-9]+", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text or None

old_m["old_name_norm"] = old_m.get("PANEL_MAIN", pd.Series(index=old_m.index)).apply(norm_text)
new_m["new_name_norm"] = new_m.get("Panel_Name", pd.Series(index=new_m.index)).apply(norm_text)

old_m["old_scale_num"] = pd.to_numeric(old_m.get("SCALE", np.nan), errors="coerce")
new_m["new_scale_num"] = pd.to_numeric(new_m.get("Pan_Scale", np.nan), errors="coerce")

# 3) Candidate pairs by spatial intersection
pairs = gpd.sjoin(
    old_m[["old_row", "PANEL_MAIN", "old_name_norm", "SCALE", "old_scale_num", "geometry"]],
    new_m[["new_row", "Panel_Name", "new_name_norm", "Pan_Scale", "new_scale_num", "geometry"]],
    how="inner",
    predicate="intersects",
)

if pairs.empty:
    match_table = pd.DataFrame(columns=[
        "old_row", "new_row", "PANEL_MAIN", "Panel_Name",
        "overlap_old_pct", "overlap_new_pct",
        "name_match_exact", "name_match_partial", "scale_match",
        "match_score", "confidence"
    ])
else:
    # 4) Compute intersection area for each candidate pair
    intersections = gpd.overlay(
        old_m[["old_row", "geometry"]],
        new_m[["new_row", "geometry"]],
        how="intersection",
    )
    intersections["intersect_m2"] = intersections.geometry.area

    overlap_area = (
        intersections.groupby(["old_row", "new_row"], as_index=False)["intersect_m2"]
        .sum()
    )

    old_area_map = old_m.set_index("old_row").geometry.area.to_dict()
    new_area_map = new_m.set_index("new_row").geometry.area.to_dict()

    match_table = (
        pairs.drop_duplicates(subset=["old_row", "new_row"])
        .merge(overlap_area, on=["old_row", "new_row"], how="left")
        .fillna({"intersect_m2": 0.0})
    )

    match_table["old_area_m2"] = match_table["old_row"].map(old_area_map)
    match_table["new_area_m2"] = match_table["new_row"].map(new_area_map)

    match_table["overlap_old_pct"] = (
        100 * match_table["intersect_m2"] / match_table["old_area_m2"].replace(0, np.nan)
    ).fillna(0).round(2)
    match_table["overlap_new_pct"] = (
        100 * match_table["intersect_m2"] / match_table["new_area_m2"].replace(0, np.nan)
    ).fillna(0).round(2)

    match_table["name_match_exact"] = (
        (match_table["old_name_norm"].notna())
        & (match_table["new_name_norm"].notna())
        & (match_table["old_name_norm"] == match_table["new_name_norm"])
    )

    match_table["name_match_partial"] = match_table.apply(
        lambda r: bool(r["old_name_norm"]) and bool(r["new_name_norm"]) and (
            r["old_name_norm"] in r["new_name_norm"] or r["new_name_norm"] in r["old_name_norm"]
        ),
        axis=1,
    )

    match_table["scale_match"] = np.isclose(
        match_table["old_scale_num"],
        match_table["new_scale_num"],
        atol=1,
        equal_nan=False,
    )

    # Weighted score: geometry-first, then name and scale agreement
    match_table["match_score"] = (
        0.55 * (match_table["overlap_old_pct"] / 100.0)
        + 0.25 * (match_table["overlap_new_pct"] / 100.0)
        + 0.15 * match_table["name_match_exact"].astype(float)
        + 0.03 * match_table["name_match_partial"].astype(float)
        + 0.02 * match_table["scale_match"].astype(float)
    ).round(4)

    match_table["confidence"] = pd.cut(
        match_table["match_score"],
        bins=[-np.inf, 0.25, 0.50, 0.75, np.inf],
        labels=["low", "medium", "high", "very_high"],
    )

    match_table = match_table.sort_values(
        by=["match_score", "overlap_old_pct", "overlap_new_pct"],
        ascending=False,
    )

# Final robust comparison table
match_table = match_table[[
    "old_row", "new_row", "PANEL_MAIN", "Panel_Name", "SCALE", "Pan_Scale",
    "overlap_old_pct", "overlap_new_pct",
    "name_match_exact", "name_match_partial", "scale_match",
    "match_score", "confidence",
]].reset_index(drop=True)

match_table.head(25)
# Out:
#     old_row  new_row                                 PANEL_MAIN  \
# 0       195       32                                 River Plym
# 1       193       36                                    Hamoaze
# 2       172       29              Plymouth Sound and Approaches
# 3         5       90              Isles of Scilly Northern Part
# 4        27       88              Isles of Scilly Southern Part
# 5       150       70                                  B Padstow
# 6         1       64                               H Porthleven
# 7        75       62                         D Penzance Harbour
# 8       180       66                             G Mullion Cove
# 9        53       64                               B Porthleven
# 10       73       59                        B Mousehole Harbour
# 11      177       34               Smeaton Pass and The Narrows
# 12       74       61                           C Newlyn Harbour
# 13      123       44       B River Tamar Calstock to Gunnislake
# 14       34       68                              E Newquay Bay
# 15       18       87        D City Docks to Saint Anne's Bridge
# 16       19       16  E River Fowey Saint Winnow to Lostwithiel
# 17      138       59                                B Mousehole
# 18       76       61                                   C Newlyn
# 19       58       23                  Nare Head to Dodman Point
# 20       54       77                                 C Minehead
# 21      182       62                                 D Penzance
# 22       61       17       D River Fowey Mixtow to Saint Winnow
# 23       91       45                            Eddystone Rocks
# 24       86       78                                  D Watchet
#
#                                      Panel_Name    SCALE  Pan_Scale  \
# 0                                    River Plym  15000.0      15000
# 1                                       Hamoaze   5000.0       5000
# 2                 Plymouth Sound and Approaches  12500.0      12500
# 3                 Isles of Scilly Northern Part  25000.0      25000
# 4                 Isles of Scilly Southern Part  25000.0      25000
# 5                                       Padstow  10000.0      10000
# 6                                    Porthleven   5000.0       5000
# 7                                      Penzance   5000.0       5000
# 8                                       Mullion   5000.0       5000
# 9                                    Porthleven   5000.0       5000
# 10                                    Mousehole   5000.0       5000
# 11                 Smeaton Pass and The Narrows   5000.0       5000
# 12                                       Newlyn   5000.0       5000
# 13           River Tamar Calstock to Gunnislake  20000.0      20000
# 14                                      Newquay  12500.0      12500
# 15             City Docks to Saint Ann's Bridge  25000.0      25000
# 16     River Fowey Saint Minnows to Lostwithiel  15000.0      15000
# 17                                    Mousehole   5000.0       5000
# 18                                       Newlyn   5000.0       5000
# 19                    Nare Head to Dodman Point  35000.0      25000
# 20                                     Minehead  20000.0      12500
# 21                                     Penzance   5000.0       5000
# 22  River Fowey Wisemans Point to Saint Minnows  15000.0      15000
# 23                              Eddystone Rocks   7500.0       7500
# 24                                      Watchet  20000.0      12500
#
#     overlap_old_pct  overlap_new_pct  name_match_exact  name_match_partial  \
# 0             92.25            98.86              True                True
# 1             84.17            99.46              True                True
# 2             79.49            99.98              True                True
# 3             79.29            98.77              True                True
# 4             76.74            95.62              True                True
# 5             99.99            99.90             False                True
# 6            100.00            99.64             False                True
# 7            100.00            99.54             False                True
# 8            100.00            99.53             False                True
# 9            100.00            99.33             False                True
# 10           100.00            99.28             False                True
# 11            74.47            95.37              True                True
# 12           100.00            98.12             False                True
# 13            97.81            98.20             False                True
# 14            99.87            89.50             False                True
# 15           100.00            98.91             False               False
# 16            99.69            98.47             False               False
# 17           100.00            84.61             False                True
# 18            99.59            85.21             False                True
# 19            89.45            53.96              True                True
# 20            99.69            86.05             False                True
# 21            92.39            93.35             False                True
# 22            95.28            98.38             False               False
# 23            59.89           100.00              True                True
# 24            99.69            80.32             False                True
#
#     scale_match  match_score confidence
# 0          True       0.9545  very_high
# 1          True       0.9116  very_high
# 2          True       0.8871  very_high
# 3          True       0.8830  very_high
# 4          True       0.8611  very_high
# 5          True       0.8497  very_high
# 6          True       0.8491  very_high
# 7          True       0.8489  very_high
# 8          True       0.8488  very_high
# 9          True       0.8483  very_high
# 10         True       0.8482  very_high
# 11         True       0.8480  very_high
# 12         True       0.8453  very_high
# 13         True       0.8335  very_high
# 14         True       0.8230  very_high
# 15         True       0.8173  very_high
# 16         True       0.8145  very_high
# 17         True       0.8115  very_high
# 18         True       0.8108  very_high
# 19        False       0.8069  very_high
# 20        False       0.7934  very_high
# 21         True       0.7915  very_high
# 22         True       0.7900  very_high
# 23         True       0.7794  very_high
# 24        False       0.7791  very_high

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

def plot_panel_overlap(panel_main, old_df=None, new_df=None, metric_crs="EPSG:27700", figsize=(9, 9)):
    """
    Plot old panel geometry, intersecting new geometries, and overlap area for a PANEL_MAIN value.
    Returns: (ax, metrics_dict)
    """
    if old_df is None:
        old_df = gdf_old
    if new_df is None:
        new_df = gdf_new

    if "PANEL_MAIN" not in old_df.columns:
        raise KeyError("old_df must contain a 'PANEL_MAIN' column.")
    if "geometry" not in old_df.columns or "geometry" not in new_df.columns:
        raise KeyError("Both dataframes must contain a geometry column.")

    panel_value = str(panel_main).strip()
    old_mask = old_df["PANEL_MAIN"].astype(str).str.strip().str.casefold() == panel_value.casefold()
    old_selected = old_df.loc[old_mask].copy()

    if old_selected.empty:
        raise ValueError(f"No old polygons found for PANEL_MAIN='{panel_main}'.")

    # Align CRS before metric reprojection
    if old_df.crs != new_df.crs:
        new_df = new_df.to_crs(old_df.crs)

    old_target = gpd.GeoDataFrame(
        {"PANEL_MAIN": [panel_value]},
        geometry=[old_selected.geometry.unary_union],
        crs=old_df.crs,
    )

    old_m = old_target.to_crs(metric_crs)
    new_m = new_df.to_crs(metric_crs).copy()

    # Candidate new polygons are those spatially intersecting the old target geometry
    new_hits = new_m[new_m.intersects(old_m.geometry.iloc[0])].copy()

    if new_hits.empty:
        fig, ax = plt.subplots(figsize=figsize)
        old_m.boundary.plot(ax=ax, color="navy", linewidth=2)
        ax.set_title(f"{panel_value}: no intersecting new polygons found")
        ax.set_axis_off()
        plt.show()
        return ax, {"old_area_m2": float(old_m.geometry.area.iloc[0]), "new_overlap_area_m2": 0.0, "overlap_pct_old": 0.0}

    overlap = gpd.overlay(
        old_m[["PANEL_MAIN", "geometry"]],
        new_hits[["geometry"]],
        how="intersection",
    )

    old_area = float(old_m.geometry.area.iloc[0])
    overlap_area = float(overlap.geometry.area.sum()) if not overlap.empty else 0.0
    overlap_pct_old = (100.0 * overlap_area / old_area) if old_area > 0 else 0.0

    fig, ax = plt.subplots(figsize=figsize)
    old_m.boundary.plot(ax=ax, color="navy", linewidth=2)
    new_hits.boundary.plot(ax=ax, color="darkorange", linewidth=1.2, alpha=0.9)

    if not overlap.empty:
        overlap.plot(ax=ax, color="limegreen", alpha=0.55, edgecolor="none")

    legend_items = [
        Line2D([0], [0], color="navy", lw=2, label="Old panel boundary"),
        Line2D([0], [0], color="darkorange", lw=1.2, label="Intersecting new boundaries"),
        Patch(facecolor="limegreen", alpha=0.55, label="Overlap area"),
    ]
    ax.legend(handles=legend_items, loc="best")
    ax.set_title(
        f"Overlap comparison for PANEL_MAIN='{panel_value}'\n"
        f"Overlap area: {overlap_area:,.0f} m^2 ({overlap_pct_old:.2f}% of old area)"
    )
    ax.set_axis_off()
    plt.tight_layout()
    plt.show()

    metrics = {
        "old_area_m2": old_area,
        "new_overlap_area_m2": overlap_area,
        "overlap_pct_old": overlap_pct_old,
        "new_polygons_intersecting": int(len(new_hits)),
    }
    return ax, metrics

# Example usage:
# ax, stats = plot_panel_overlap("Isles of Scilly Northern Part")
# stats

# %%
ax, stats = plot_panel_overlap("Isles of Scilly Northern Part")
stats
# Out:
# C:\Users\anileshw\AppData\Local\Temp\7\ipykernel_19576\1503649199.py:33: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   geometry=[old_selected.geometry.unary_union],
# {'old_area_m2': 130920885.20706767,
#  'new_overlap_area_m2': 273829119.3265157,
#  'overlap_pct_old': 209.1561777125329,
#  'new_polygons_intersecting': 4}

# %%
ax, stats = plot_panel_overlap("River Plym")
stats
# Out:
# C:\Users\anileshw\AppData\Local\Temp\7\ipykernel_19576\1503649199.py:33: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   geometry=[old_selected.geometry.unary_union],
# {'old_area_m2': 5356898.077413635,
#  'new_overlap_area_m2': 8093301.192486132,
#  'overlap_pct_old': 151.0818588580214,
#  'new_polygons_intersecting': 3}
